# %%
# import library
library(tidyverse)
library(cowplot)

options(repr.plot.width = 20, repr.plot.height = 10)

# %%
# read dataset
cancer <- read_csv('dataR2.csv')
head(cancer)
# Out:
# Rows: 116 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (10): Age, BMI, Glucose, Insulin, HOMA, Leptin, Adiponectin, Resistin, M...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Age BMI      Glucose Insulin HOMA      Leptin  Adiponectin Resistin MCP.1
# 1 48  23.50000 70      2.707   0.4674087  8.8071  9.702400    7.99585 417.114
# 2 83  20.69049 92      3.115   0.7068973  8.8438  5.429285    4.06405 468.786
# 3 82  23.12467 91      4.498   1.0096511 17.9393 22.432040    9.27715 554.697
# 4 68  21.36752 77      3.226   0.6127249  9.8827  7.169560   12.76600 928.220
# 5 86  21.11111 92      3.549   0.8053864  6.6994  4.819240   10.57635 773.920
# 6 49  22.85446 92      3.226   0.7320869  6.8317 13.679750   10.31760 530.410
#   Classification
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %%
# filter control data
control <- cancer %>%
    filter(Classification == 1) %>%
    select(!Classification)
head(control)
# Out:
#   Age BMI      Glucose Insulin HOMA      Leptin  Adiponectin Resistin MCP.1
# 1 48  23.50000 70      2.707   0.4674087  8.8071  9.702400    7.99585 417.114
# 2 83  20.69049 92      3.115   0.7068973  8.8438  5.429285    4.06405 468.786
# 3 82  23.12467 91      4.498   1.0096511 17.9393 22.432040    9.27715 554.697
# 4 68  21.36752 77      3.226   0.6127249  9.8827  7.169560   12.76600 928.220
# 5 86  21.11111 92      3.549   0.8053864  6.6994  4.819240   10.57635 773.920
# 6 49  22.85446 92      3.226   0.7320869  6.8317 13.679750   10.31760 530.410

# %%
# filter patient data
patient <- cancer %>%
    filter(Classification == 2) %>%
    select(!Classification)
head(patient)
# Out:
#   Age BMI      Glucose Insulin HOMA      Leptin  Adiponectin Resistin MCP.1
# 1 45  21.30395 102     13.852  3.4851632  7.6476 21.056625   23.03408 552.444
# 2 45  20.83000  74      4.560  0.8323520  7.7529  8.237405   28.03230 382.955
# 3 49  20.95661  94     12.305  2.8531193 11.2406  8.412175   23.11770 573.630
# 4 34  24.24242  92     21.699  4.9242264 16.7353 21.823745   12.06534 481.949
# 5 42  21.35991  93      2.999  0.6879706 19.0826  8.462915   17.37615 321.919
# 6 68  21.08281 102      6.200  1.5599200  9.6994  8.574655   13.74244 448.799

# %%
# create a function for generating control v.s. patient plots with variable s
control_vs_patient_plots <- function(s) {
    control_s_dist <- control %>%
        ggplot(aes_string(x = s)) +
        geom_histogram(binwidth = 5) + 
        labs(x = s, title = paste('Distribution of Healthy Control', s)) +
        theme(text = element_text(size=20))
    
    patient_s_dist <- patient %>%
        ggplot(aes_string(x = s)) +
        geom_histogram(binwidth = 5) + 
        labs(x = s, title = paste('Distribution of Patient', s)) +
        theme(text = element_text(size=20))
  return(plot_grid(control_s_dist, patient_s_dist))
}

# %%
control_vs_patient_plots("Age")
# Out:
# plot without title

# %%
control_vs_patient_plots("BMI")
# Out:
# plot without title

# %%
control_vs_patient_plots("Glucose")
# Out:
# plot without title

# %%
control_vs_patient_plots("Insulin")
# Out:
# plot without title

# %%
control_vs_patient_plots("HOMA")
# Out:
# plot without title

# %%
control_vs_patient_plots("Leptin")
# Out:
# plot without title

# %%
control_vs_patient_plots("Adiponectin")
# Out:
# plot without title

# %%
control_vs_patient_plots("Resistin")
# Out:
# plot without title

# %%
control_vs_patient_plots("MCP.1")
# Out:
# plot without title
